# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY0"]=os.getenv(" GROQ_API_KEY")
os.environ["GROQ_API_KEY0"]=os.getenv(" GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model

model=init_chat_model("google_genai:llama-3.1-8b-instant")
