# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")

# %% [markdown]
# using gemini

# %%
from langchain.chat_models import init_chat_model

model=init_chat_model("google_genai:gemma-3-27b-it")
response=model.invoke("why sea water is salty")
response.content
# Out:
# "Okay, let's break down why seawater is salty! It's a surprisingly complex answer, but here's a comprehensive explanation, covering the main sources and processes:\n\n**1. Weathering and Erosion of Rocks on Land (The Biggest Contributor)**\n\n* **The Process:** Rainwater is naturally slightly acidic (due to dissolved carbon dioxide from the atmosphere). When this acidic rainwater falls on land, it slowly dissolves minerals from rocks. This is called weathering.\n* **What gets dissolved?**  Rocks contain salts and minerals, including sodium chloride (table salt), magnesium, calcium, potassium, and others.\n* **The Journey to the Sea:**  The dissolved minerals are carried by rivers and streams to the ocean.  Think of rivers as constantly delivering tiny amounts of dissolved salts to the sea.\n* **Why it accumulates:** Water evaporates from the ocean, but the salts *don't*.  This means the salts are left behind, gradually building up over billions of years.  This is the primary reason f
# ...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage

# Initialize Gemini model
# gemini_model = ChatGoogleGenerativeAI(
#     model="gemini-2.5-flash-lite",
#     google_api_key=os.getenv("GOOGLE_API_KEY"),
#     temperature=0.7
# )
gemini_model = ChatGoogleGenerativeAI(
    model="gemma-3-27b-it"
)
response = gemini_model.invoke("why sea water is salty")
response.content
# Out:
# "Okay, let's break down why seawater is salty! It's a surprisingly complex answer, but here's a comprehensive explanation, covering the main sources and processes:\n\n**1. Weathering and Erosion of Rocks on Land (The Biggest Contributor)**\n\n* **The Process:** Rainwater is naturally slightly acidic (due to dissolved carbon dioxide from the atmosphere). When this acidic rainwater falls on land, it slowly dissolves minerals from rocks. This is called weathering.\n* **What gets dissolved?**  Rocks contain salts and minerals, including sodium chloride (table salt), magnesium, calcium, potassium, and others.\n* **The Journey to the Sea:**  The dissolved minerals are carried by rivers and streams to the ocean.  Think of rivers as constantly delivering tiny amounts of dissolved salts to the sea.\n* **Why it accumulates:** Water evaporates from the ocean, but the *salts* don't.  They are left behind, gradually increasing the concentration of salt over billions of years.\n\n**2. Hydrothermal
# ...

# %% [markdown]
# using groq

# %%
from langchain.chat_models import init_chat_model

model=init_chat_model("groq:llama-3.1-8b-instant")
response=model.invoke("why sea water is salty")
response.content
# Out:
# d:\Learning\AI projects\Langchain_projects-Langchain_2\venv\Lib\site-packages\langchain_core\_api\deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1
# ...

# %%
print(model.stream("explain how earth is formed"))
# Out:
# <generator object BaseChatModel.stream at 0x000001996E324040>

# %%
for chunk in model.stream("explain how earth is formed"):
    print(chunk.content,end='')
# Out:
# The formation of Earth is a complex and still somewhat debated topic in the field of astrophysics and planetary science. However, based on the current understanding and evidence, here's a step-by-step explanation of how Earth is believed to have formed:
#
# **Stage 1: The Formation of the Solar System (4.6 billion years ago)**
#
# The solar system is thought to have formed from a giant cloud of gas and dust called a solar nebula. This nebula was composed of hydrogen, helium, and heavier elements formed in the hearts of ancient stars. Gravity caused the nebula to collapse, and it began to spin faster and faster.
#
# **Stage 2: The Accretion Disk (4.5 billion years ago)**
#
# As the nebula collapsed, it flattened into a disk shape, with the Sun at its center. This disk, called the accretion disk, was made up of particles ranging from dust to boulders. These particles collided and merged, growing larger and more massive.
#
# **Stage 3: Planetesimal Formation (4.4 billion years ago)**
#
# ...

# %%
from langchain_core.messages import HumanMessage,AIMessage

# %%
messages=[AIMessage(content="how can i help you",name="model")]
messages.append(HumanMessage(content="narate me a poem",name="rk"))

# %%
messages
# Out:
# [AIMessage(content='how can i help you', additional_kwargs={}, response_metadata={}, name='model', tool_calls=[], invalid_tool_calls=[]),
#  HumanMessage(content='narate me a poem', additional_kwargs={}, response_metadata={}, name='rk')]

# %%
response=model.invoke(messages)

# %%
response.content
# Out:
# "In twilight's hush, where shadows play,\nA midnight breeze whispers through the day,\nThe stars above, a twinkling sea,\nA celestial show, for you and me.\n\nThe moon, a glowing crescent smile,\nLends gentle light, to a peaceful while,\nThe world is still, in a quiet sleep,\nAs the night's dark magic, begins to creep.\n\nIn this soft silence, I find my peace,\nA sense of calm, that the world can't release,\nThe stars up high, they twinkle and spin,\nA cosmic dance, that draws me in.\n\nThe wind it whispers, through the trees so tall,\nA gentle lullaby, that echoes through it all,\nThe night's dark beauty, it wraps around me tight,\nA sense of wonder, that fills my heart with light.\n\nSo let us bask, in this peaceful night,\nAnd let the stars, shine with all their light,\nFor in their twinkling, we find our way,\nTo a place of peace, where love will stay.\n\nThe poem is a gentle and soothing tale that captures the beauty of a peaceful night, under the stars. It takes us on a journey
# ...

# %%
for i in messages:
    i.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: model
#
# how can i help you
# ================================ Human Message =================================
# Name: rk
#
# narate me a poem
